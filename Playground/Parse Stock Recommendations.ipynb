# %% [markdown]
# Resources:
# - https://towardsdatascience.com/parse-thousands-of-stock-recommendations-in-minutes-with-python-6e3e562f156d
# - https://github.com/atreadw1492/yahoo_fin
# - http://theautomatic.net/yahoo_fin-documentation/

# %%
import requests
import pandas as pd 
from yahoo_fin import stock_info as si 
from pandas_datareader import DataReader
import numpy as np

tickers = si.tickers_sp500()
recommendations = []

for ticker in tickers:
    lhs_url = 'https://query2.finance.yahoo.com/v10/finance/quoteSummary/'
    rhs_url = '?formatted=true&crumb=swg7qs5y9UP&lang=en-US&region=US&' \
              'modules=upgradeDowngradeHistory,recommendationTrend,' \
              'financialData,earningsHistory,earningsTrend,industryTrend&' \
              'corsDomain=finance.yahoo.com'
              
    url =  lhs_url + ticker + rhs_url
    r = requests.get(url)
    if not r.ok:
        recommendation = 6
    try:
        result = r.json()['quoteSummary']['result'][0]
        recommendation =result['financialData']['recommendationMean']['fmt']
    except:
        recommendation = 6
    
    recommendations.append(recommendation)
    
    print("--------------------------------------------")
    print ("{} has an average recommendation of: ".format(ticker), recommendation)
    #time.sleep(0.5)
    
dataframe = pd.DataFrame(list(zip(tickers, recommendations)), columns =['Company', 'Recommendations']) 
dataframe = dataframe.set_index('Company')
# Out:
# C:\Users\tjtek\anaconda3\lib\site-packages\yahoo_fin\stock_info.py:130: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   sp500["Symbol"] = sp500["Symbol"].str.replace(".", "-")
# --------------------------------------------
# A has an average recommendation of:  1.90
# --------------------------------------------
# AAL has an average recommendation of:  3.40
# --------------------------------------------
# AAP has an average recommendation of:  2.20
# --------------------------------------------
# AAPL has an average recommendation of:  2.00
# --------------------------------------------
# ABBV has an average recommendation of:  2.00
# --------------------------------------------
# ABC has an average recommendation of:  2.20
# --------------------------------------------
# ABMD has an average recommendation of:  2.30
# --------------------------------------------
# ABT has an average recommendation of:  1.80
# --------------------------------------------
# ACN has an average recommendation of:  2.10
# --------------------------------------------
# ADBE has an average recommendation of:  1.70
# --------------------------------------------
# ADI has an average recommendation of:  1.80
# --------------------------------------------
# ADM has an average recommendation of:  1.70
# --------------------------------------------
# ADP has an average recommendation of:  2.90
# --------------------------------------------
# ADSK has an average recommendation of:  1.90
# --------------------------------------------
# AEE has an average recommendation of:  2.10
# --------------------------------------------
# AEP has an average recommendation of:  2.30
# --------------------------------------------
# AES has an average recommendation of:  1.90
# --------------------------------------------
# AFL has an average recommendation of:  2.90
# --------------------------------------------
# AIG has an average recommendation of:  2.40
# --------------------------------------------
# AIZ has an average recommendation of:  1.80
# --------------------------------------------
# AJG has an average recommendation of:  2.00
# --------------------------------------------
# AKAM has an average recommendation of:  2.00
# --------------------------------------------
# ALB has an average recommendation of:  2.60
# --------------------------------------------
# ALGN has an average recommendation of:  2.00
# --------------------------------------------
# ALK has an average recommendation of:  1.90
# --------------------------------------------
# ALL has an average recommendation of:  2.20
# --------------------------------------------
# ALLE has an average recommendation of:  2.60
# --------------------------------------------
# ALXN has an average recommendation of:  2.70
# --------------------------------------------
# AMAT has an average recommendation of:  1.90
# --------------------------------------------
# AMCR has an average recommendation of:  2.90
# --------------------------------------------
# AMD has an average recommendation of:  2.30
# --------------------------------------------
# AME has an average recommendation of:  2.10
# --------------------------------------------
# AMGN has an average recommendation of:  2.40
# --------------------------------------------
# AMP has an average recommendation of:  1.80
# --------------------------------------------
# AMT has an average recommendation of:  1.90
# --------------------------------------------
# AMZN has an average recommendation of:  1.70
# --------------------------------------------
# ANET has an average recommendation of:  2.30
# --------------------------------------------
# ANSS has an average recommendation of:  2.40
# --------------------------------------------
# ANTM has an average recommendation of:  1.90
# --------------------------------------------
# AON has an average recommendation of:  2.40
# --------------------------------------------
# AOS has an average recommendation of:  2.70
# --------------------------------------------
# APA has an average recommendation of:  2.30
# --------------------------------------------
# APD has an average recommendation of:  2.40
# --------------------------------------------
# APH has an average recommendation of:  2.20
# --------------------------------------------
# APTV has an average recommendation of:  2.20
# --------------------------------------------
# ARE has an average recommendation of:  1.60
# --------------------------------------------
# ATO has an average recommendation of:  2.40
# --------------------------------------------
# ATVI has an average recommendation of:  1.90
# --------------------------------------------
# AVB has an average recommendation of:  2.60
# --------------------------------------------
# AVGO has an average recommendation of:  2.00
# --------------------------------------------
# AVY has an average recommendation of:  2.10
# --------------------------------------------
# AWK has an average recommendation of:  2.40
# --------------------------------------------
# AXP has an average recommendation of:  2.40
# --------------------------------------------
# AZO has an average recommendation of:  2.10
# --------------------------------------------
# BA has an average recommendation of:  2.60
# --------------------------------------------
# BAC has an average recommendation of:  2.30
# --------------------------------------------
# BAX has an average recommendation of:  2.10
# --------------------------------------------
# BBY has an average recommendation of:  2.60
# --------------------------------------------
# BDX has an average recommendation of:  2.10
# --------------------------------------------
# BEN has an average recommendation of:  3.20
# --------------------------------------------
# BF-B has an average recommendation of:  3.30
# --------------------------------------------
# BIIB has an average recommendation of:  2.80
# --------------------------------------------
# BIO has an average recommendation of:  1.50
# --------------------------------------------
# BK has an average recommendation of:  2.20
# --------------------------------------------
# BKNG has an average recommendation of:  2.60
# --------------------------------------------
# BKR has an average recommendation of:  1.90
# --------------------------------------------
# BLK has an average recommendation of:  1.90
# --------------------------------------------
# BLL has an average recommendation of:  2.30
# --------------------------------------------
# BMY has an average recommendation of:  1.90
# --------------------------------------------
# BR has an average recommendation of:  2.50
# --------------------------------------------
# BRK-B has an average recommendation of:  2.20
# --------------------------------------------
# BSX has an average recommendation of:  1.70
# --------------------------------------------
# BWA has an average recommendation of:  2.40
# --------------------------------------------
# BXP has an average recommendation of:  2.50
# --------------------------------------------
# C has an average recommendation of:  2.10
# --------------------------------------------
# CAG has an average recommendation of:  2.40
# --------------------------------------------
# CAH has an average recommendation of:  2.50
# --------------------------------------------
# CARR has an average recommendation of:  2.00
# --------------------------------------------
# CAT has an average recommendation of:  2.60
# --------------------------------------------
# CB has an average recommendation of:  2.20
# --------------------------------------------
# CBOE has an average recommendation of:  2.60
# --------------------------------------------
# CBRE has an average recommendation of:  2.10
# --------------------------------------------
# CCI has an average recommendation of:  2.20
# --------------------------------------------
# CCL has an average recommendation of:  2.60
# --------------------------------------------
# CDNS has an average recommendation of:  2.30
# --------------------------------------------
# CDW has an average recommendation of:  2.00
# --------------------------------------------
# CE has an average recommendation of:  2.30
# --------------------------------------------
# CERN has an average recommendation of:  2.40
# --------------------------------------------
# CF has an average recommendation of:  2.20
# --------------------------------------------
# CFG has an average recommendation of:  2.10
# --------------------------------------------
# CHD has an average recommendation of:  2.60
# --------------------------------------------
# CHRW has an average recommendation of:  3.00
# --------------------------------------------
# CHTR has an average recommendation of:  2.20
# --------------------------------------------
# CI has an average recommendation of:  1.80
# --------------------------------------------
# CINF has an average recommendation of:  2.80
# --------------------------------------------
# CL has an average recommendation of:  2.90
# --------------------------------------------
# CLX has an average recommendation of:  2.90
# --------------------------------------------
# CMA has an average recommendation of:  2.90
# --------------------------------------------
# CMCSA has an average recommendation of:  2.00
# --------------------------------------------
# CME has an average recommendation of:  2.50
# --------------------------------------------
# CMG has an average recommendation of:  2.10
# --------------------------------------------
# CMI has an average recommendation of:  2.40
# --------------------------------------------
# CMS has an average recommendation of:  2.40
# --------------------------------------------
# CNC has an average recommendation of:  1.90
# --------------------------------------------
# CNP has an average recommendation of:  2.10
# --------------------------------------------
# COF has an average recommendation of:  1.90
# --------------------------------------------
# COG has an average recommendation of:  2.50
# --------------------------------------------
# COO has an average recommendation of:  2.20
# --------------------------------------------
# COP has an average recommendation of:  1.80
# --------------------------------------------
# COST has an average recommendation of:  2.10
# --------------------------------------------
# CPB has an average recommendation of:  2.90
# --------------------------------------------
# CPRT has an average recommendation of:  1.70
# --------------------------------------------
# CRM has an average recommendation of:  1.90
# --------------------------------------------
# CSCO has an average recommendation of:  2.20
# --------------------------------------------
# CSX has an average recommendation of:  2.20
# --------------------------------------------
# CTAS has an average recommendation of:  2.30
# --------------------------------------------
# CTLT has an average recommendation of:  1.70
# --------------------------------------------
# CTSH has an average recommendation of:  2.50
# --------------------------------------------
# CTVA has an average recommendation of:  2.50
# --------------------------------------------
# CTXS has an average recommendation of:  2.30
# --------------------------------------------
# CVS has an average recommendation of:  2.10
# --------------------------------------------
# CVX has an average recommendation of:  2.30
# --------------------------------------------
# CZR has an average recommendation of:  2.00
# --------------------------------------------
# D has an average recommendation of:  2.20
# --------------------------------------------
# DAL has an average recommendation of:  2.40
# --------------------------------------------
# DD has an average recommendation of:  2.20
# --------------------------------------------
# DE has an average recommendation of:  2.20
# --------------------------------------------
# DFS has an average recommendation of:  2.20
# --------------------------------------------
# DG has an average recommendation of:  1.90
# --------------------------------------------
# DGX has an average recommendation of:  2.10
# --------------------------------------------
# DHI has an average recommendation of:  1.90
# --------------------------------------------
# DHR has an average recommendation of:  1.80
# --------------------------------------------
# DIS has an average recommendation of:  2.00
# --------------------------------------------
# DISCA has an average recommendation of:  2.70
# --------------------------------------------
# DISCK has an average recommendation of:  3.00
# --------------------------------------------
# DISH has an average recommendation of:  2.60
# --------------------------------------------
# DLR has an average recommendation of:  2.10
# --------------------------------------------
# DLTR has an average recommendation of:  2.40
# --------------------------------------------
# DOV has an average recommendation of:  2.20
# --------------------------------------------
# DOW has an average recommendation of:  2.70
# --------------------------------------------
# DPZ has an average recommendation of:  2.20
# --------------------------------------------
# DRE has an average recommendation of:  2.10
# --------------------------------------------
# DRI has an average recommendation of:  2.10
# --------------------------------------------
# DTE has an average recommendation of:  2.40
# --------------------------------------------
# DUK has an average recommendation of:  2.60
# --------------------------------------------
# DVA has an average recommendation of:  2.90
# --------------------------------------------
# DVN has an average recommendation of:  1.80
# --------------------------------------------
# DXC has an average recommendation of:  2.60
# --------------------------------------------
# DXCM has an average recommendation of:  1.70
# --------------------------------------------
# EA has an average recommendation of:  2.10
# --------------------------------------------
# EBAY has an average recommendation of:  2.50
# --------------------------------------------
# ECL has an average recommendation of:  2.60
# --------------------------------------------
# ED has an average recommendation of:  3.50
# --------------------------------------------
# EFX has an average recommendation of:  2.30
# --------------------------------------------
# EIX has an average recommendation of:  2.00
# --------------------------------------------
# EL has an average recommendation of:  2.00
# --------------------------------------------
# EMN has an average recommendation of:  2.20
# --------------------------------------------
# EMR has an average recommendation of:  2.20
# --------------------------------------------
# ENPH has an average recommendation of:  2.20
# --------------------------------------------
# EOG has an average recommendation of:  2.20
# --------------------------------------------
# EQIX has an average recommendation of:  1.80
# --------------------------------------------
# EQR has an average recommendation of:  2.90
# --------------------------------------------
# ES has an average recommendation of:  2.50
# --------------------------------------------
# ESS has an average recommendation of:  2.50
# --------------------------------------------
# ETN has an average recommendation of:  2.00
# --------------------------------------------
# ETR has an average recommendation of:  2.00
# --------------------------------------------
# ETSY has an average recommendation of:  1.70
# --------------------------------------------
# EVRG has an average recommendation of:  1.70
# --------------------------------------------
# EW has an average recommendation of:  2.20
# --------------------------------------------
# EXC has an average recommendation of:  2.20
# --------------------------------------------
# EXPD has an average recommendation of:  3.20
# --------------------------------------------
# EXPE has an average recommendation of:  2.30
# --------------------------------------------
# EXR has an average recommendation of:  2.20
# --------------------------------------------
# F has an average recommendation of:  2.50
# --------------------------------------------
# FANG has an average recommendation of:  1.90
# --------------------------------------------
# FAST has an average recommendation of:  2.80
# --------------------------------------------
# FB has an average recommendation of:  1.80
# --------------------------------------------
# FBHS has an average recommendation of:  2.50
# --------------------------------------------
# FCX has an average recommendation of:  2.00
# --------------------------------------------
# FDX has an average recommendation of:  2.00
# --------------------------------------------
# FE has an average recommendation of:  2.40
# --------------------------------------------
# FFIV has an average recommendation of:  2.40
# --------------------------------------------
# FIS has an average recommendation of:  1.90
# --------------------------------------------
# FISV has an average recommendation of:  1.80
# --------------------------------------------
# FITB has an average recommendation of:  1.90
# --------------------------------------------
# FLIR has an average recommendation of:  3.00
# --------------------------------------------
# FLT has an average recommendation of:  2.10
# --------------------------------------------
# FMC has an average recommendation of:  1.90
# --------------------------------------------
# FOX has an average recommendation of:  6
# --------------------------------------------
# FOXA has an average recommendation of:  2.50
# --------------------------------------------
# FRC has an average recommendation of:  2.50
# --------------------------------------------
# FRT has an average recommendation of:  2.90
# --------------------------------------------
# FTNT has an average recommendation of:  2.10
# --------------------------------------------
# FTV has an average recommendation of:  2.40
# --------------------------------------------
# GD has an average recommendation of:  2.40
# --------------------------------------------
# GE has an average recommendation of:  2.10
# --------------------------------------------
# GILD has an average recommendation of:  2.30
# --------------------------------------------
# GIS has an average recommendation of:  2.90
# --------------------------------------------
# GL has an average recommendation of:  2.90
# --------------------------------------------
# GLW has an average recommendation of:  1.90
# --------------------------------------------
# GM has an average recommendation of:  1.80
# --------------------------------------------
# GNRC has an average recommendation of:  1.70
# --------------------------------------------
# GOOG has an average recommendation of:  1.50
# --------------------------------------------
# GOOGL has an average recommendation of:  1.70
# --------------------------------------------
# GPC has an average recommendation of:  2.80
# --------------------------------------------
# GPN has an average recommendation of:  1.90
# --------------------------------------------
# GPS has an average recommendation of:  2.80
# --------------------------------------------
# GRMN has an average recommendation of:  2.20
# --------------------------------------------
# GS has an average recommendation of:  2.20
# --------------------------------------------
# GWW has an average recommendation of:  2.60
# --------------------------------------------
# HAL has an average recommendation of:  2.40
# --------------------------------------------
# HAS has an average recommendation of:  1.90
# --------------------------------------------
# HBAN has an average recommendation of:  2.20
# --------------------------------------------
# HBI has an average recommendation of:  2.50
# --------------------------------------------
# HCA has an average recommendation of:  2.00
# --------------------------------------------
# HD has an average recommendation of:  2.10
# --------------------------------------------
# HES has an average recommendation of:  2.10
# --------------------------------------------
# HFC has an average recommendation of:  2.80
# --------------------------------------------
# HIG has an average recommendation of:  2.10
# --------------------------------------------
# HII has an average recommendation of:  2.60
# --------------------------------------------
# HLT has an average recommendation of:  2.30
# --------------------------------------------
# HOLX has an average recommendation of:  1.80
# --------------------------------------------
# HON has an average recommendation of:  2.20
# --------------------------------------------
# HPE has an average recommendation of:  2.50
# --------------------------------------------
# HPQ has an average recommendation of:  2.60
# --------------------------------------------
# HRL has an average recommendation of:  3.20
# --------------------------------------------
# HSIC has an average recommendation of:  2.50
# --------------------------------------------
# HST has an average recommendation of:  2.70
# --------------------------------------------
# HSY has an average recommendation of:  2.40
# --------------------------------------------
# HUM has an average recommendation of:  2.00
# --------------------------------------------
# HWM has an average recommendation of:  2.00
# --------------------------------------------
# IBM has an average recommendation of:  2.60
# --------------------------------------------
# ICE has an average recommendation of:  1.80
# --------------------------------------------
# IDXX has an average recommendation of:  1.90
# --------------------------------------------
# IEX has an average recommendation of:  2.20
# --------------------------------------------
# IFF has an average recommendation of:  2.10
# --------------------------------------------
# ILMN has an average recommendation of:  2.70
# --------------------------------------------
# INCY has an average recommendation of:  2.20
# --------------------------------------------
# INFO has an average recommendation of:  2.00
# --------------------------------------------
# INTC has an average recommendation of:  2.80
# --------------------------------------------
# INTU has an average recommendation of:  1.90
# --------------------------------------------
# IP has an average recommendation of:  2.50
# --------------------------------------------
# IPG has an average recommendation of:  2.40
# --------------------------------------------
# IPGP has an average recommendation of:  2.10
# --------------------------------------------
# IQV has an average recommendation of:  1.70
# --------------------------------------------
# IR has an average recommendation of:  2.10
# --------------------------------------------
# IRM has an average recommendation of:  2.60
# --------------------------------------------
# ISRG has an average recommendation of:  2.20
# --------------------------------------------
# IT has an average recommendation of:  2.00
# --------------------------------------------
# ITW has an average recommendation of:  2.80
# --------------------------------------------
# IVZ has an average recommendation of:  2.90
# --------------------------------------------
# J has an average recommendation of:  1.70
# --------------------------------------------
# JBHT has an average recommendation of:  2.20
# --------------------------------------------
# JCI has an average recommendation of:  2.30
# --------------------------------------------
# JKHY has an average recommendation of:  2.60
# --------------------------------------------
# JNJ has an average recommendation of:  1.90
# --------------------------------------------
# JNPR has an average recommendation of:  3.10
# --------------------------------------------
# JPM has an average recommendation of:  2.30
# --------------------------------------------
# K has an average recommendation of:  2.70
# --------------------------------------------
# KEY has an average recommendation of:  2.70
# --------------------------------------------
# KEYS has an average recommendation of:  1.80
# --------------------------------------------
# KHC has an average recommendation of:  2.80
# --------------------------------------------
# KIM has an average recommendation of:  2.30
# --------------------------------------------
# KLAC has an average recommendation of:  2.30
# --------------------------------------------
# KMB has an average recommendation of:  2.90
# --------------------------------------------
# KMI has an average recommendation of:  2.80
# --------------------------------------------
# KMX has an average recommendation of:  1.70
# --------------------------------------------
# KO has an average recommendation of:  2.10
# --------------------------------------------
# KR has an average recommendation of:  2.80
# --------------------------------------------
# KSU has an average recommendation of:  2.50
# --------------------------------------------
# L has an average recommendation of:  3.00
# --------------------------------------------
# LB has an average recommendation of:  2.50
# --------------------------------------------
# LDOS has an average recommendation of:  1.60
# --------------------------------------------
# LEG has an average recommendation of:  2.50
# --------------------------------------------
# LEN has an average recommendation of:  2.30
# --------------------------------------------
# LH has an average recommendation of:  1.80
# --------------------------------------------
# LHX has an average recommendation of:  2.00
# --------------------------------------------
# LIN has an average recommendation of:  1.90
# --------------------------------------------
# LKQ has an average recommendation of:  1.60
# --------------------------------------------
# LLY has an average recommendation of:  2.10
# --------------------------------------------
# LMT has an average recommendation of:  2.20
# --------------------------------------------
# LNC has an average recommendation of:  2.60
# --------------------------------------------
# LNT has an average recommendation of:  1.90
# --------------------------------------------
# LOW has an average recommendation of:  1.80
# --------------------------------------------
# LRCX has an average recommendation of:  2.00
# --------------------------------------------
# LUMN has an average recommendation of:  3.40
# --------------------------------------------
# LUV has an average recommendation of:  1.90
# --------------------------------------------
# LVS has an average recommendation of:  2.10
# --------------------------------------------
# LW has an average recommendation of:  2.30
# --------------------------------------------
# LYB has an average recommendation of:  2.50
# --------------------------------------------
# LYV has an average recommendation of:  2.30
# --------------------------------------------
# MA has an average recommendation of:  1.80
# --------------------------------------------
# MAA has an average recommendation of:  2.60
# --------------------------------------------
# MAR has an average recommendation of:  2.50
# --------------------------------------------
# MAS has an average recommendation of:  2.40
# --------------------------------------------
# MCD has an average recommendation of:  2.00
# --------------------------------------------
# MCHP has an average recommendation of:  2.00
# --------------------------------------------
# MCK has an average recommendation of:  1.80
# --------------------------------------------
# MCO has an average recommendation of:  2.10
# --------------------------------------------
# MDLZ has an average recommendation of:  1.80
# --------------------------------------------
# MDT has an average recommendation of:  1.90
# --------------------------------------------
# MET has an average recommendation of:  1.90
# --------------------------------------------
# MGM has an average recommendation of:  2.60
# --------------------------------------------
# MHK has an average recommendation of:  2.50
# --------------------------------------------
# MKC has an average recommendation of:  3.10
# --------------------------------------------
# MKTX has an average recommendation of:  2.70
# --------------------------------------------
# MLM has an average recommendation of:  2.40
# --------------------------------------------
# MMC has an average recommendation of:  2.80
# --------------------------------------------
# MMM has an average recommendation of:  3.00
# --------------------------------------------
# MNST has an average recommendation of:  2.10
# --------------------------------------------
# MO has an average recommendation of:  2.20
# --------------------------------------------
# MOS has an average recommendation of:  2.30
# --------------------------------------------
# MPC has an average recommendation of:  1.90
# --------------------------------------------
# MPWR has an average recommendation of:  1.80
# --------------------------------------------
# MRK has an average recommendation of:  2.00
# --------------------------------------------
# MRO has an average recommendation of:  2.50
# --------------------------------------------
# MS has an average recommendation of:  2.00
# --------------------------------------------
# MSCI has an average recommendation of:  2.30
# --------------------------------------------
# MSFT has an average recommendation of:  1.60
# --------------------------------------------
# MSI has an average recommendation of:  1.80
# --------------------------------------------
# MTB has an average recommendation of:  2.60
# --------------------------------------------
# MTD has an average recommendation of:  3.20
# --------------------------------------------
# MU has an average recommendation of:  1.90
# --------------------------------------------
# MXIM has an average recommendation of:  2.80
# --------------------------------------------
# NCLH has an average recommendation of:  2.40
# --------------------------------------------
# NDAQ has an average recommendation of:  2.30
# --------------------------------------------
# NEE has an average recommendation of:  2.00
# --------------------------------------------
# NEM has an average recommendation of:  2.00
# --------------------------------------------
# NFLX has an average recommendation of:  2.00
# --------------------------------------------
# NI has an average recommendation of:  1.90
# --------------------------------------------
# NKE has an average recommendation of:  1.90
# --------------------------------------------
# NLOK has an average recommendation of:  2.20
# --------------------------------------------
# NLSN has an average recommendation of:  2.10
# --------------------------------------------
# NOC has an average recommendation of:  2.00
# --------------------------------------------
# NOV has an average recommendation of:  2.40
# --------------------------------------------
# NOW has an average recommendation of:  1.70
# --------------------------------------------
# NRG has an average recommendation of:  2.10
# --------------------------------------------
# NSC has an average recommendation of:  2.30
# --------------------------------------------
# NTAP has an average recommendation of:  2.50
# --------------------------------------------
# NTRS has an average recommendation of:  2.90
# --------------------------------------------
# NUE has an average recommendation of:  2.40
# --------------------------------------------
# NVDA has an average recommendation of:  2.00
# --------------------------------------------
# NVR has an average recommendation of:  2.70
# --------------------------------------------
# NWL has an average recommendation of:  2.70
# --------------------------------------------
# NWS has an average recommendation of:  6
# --------------------------------------------
# NWSA has an average recommendation of:  1.90
# --------------------------------------------
# NXPI has an average recommendation of:  2.20
# --------------------------------------------
# O has an average recommendation of:  2.20
# --------------------------------------------
# ODFL has an average recommendation of:  2.30
# --------------------------------------------
# OKE has an average recommendation of:  2.80
# --------------------------------------------
# OMC has an average recommendation of:  2.70
# --------------------------------------------
# ORCL has an average recommendation of:  2.80
# --------------------------------------------
# ORLY has an average recommendation of:  2.10
# --------------------------------------------
# OTIS has an average recommendation of:  2.20
# --------------------------------------------
# OXY has an average recommendation of:  2.90
# --------------------------------------------
# PAYC has an average recommendation of:  1.80
# --------------------------------------------
# PAYX has an average recommendation of:  3.00
# --------------------------------------------
# PBCT has an average recommendation of:  3.00
# --------------------------------------------
# PCAR has an average recommendation of:  2.60
# --------------------------------------------
# PEAK has an average recommendation of:  2.30
# --------------------------------------------
# PEG has an average recommendation of:  2.30
# --------------------------------------------
# PENN has an average recommendation of:  2.40
# --------------------------------------------
# PEP has an average recommendation of:  2.30
# --------------------------------------------
# PFE has an average recommendation of:  2.60
# --------------------------------------------
# PFG has an average recommendation of:  2.70
# --------------------------------------------
# PG has an average recommendation of:  2.50
# --------------------------------------------
# PGR has an average recommendation of:  2.70
# --------------------------------------------
# PH has an average recommendation of:  2.00
# --------------------------------------------
# PHM has an average recommendation of:  2.20
# --------------------------------------------
# PKG has an average recommendation of:  2.80
# --------------------------------------------
# PKI has an average recommendation of:  2.20
# --------------------------------------------
# PLD has an average recommendation of:  1.90
# --------------------------------------------
# PM has an average recommendation of:  2.00
# --------------------------------------------
# PNC has an average recommendation of:  2.60
# --------------------------------------------
# PNR has an average recommendation of:  2.60
# --------------------------------------------
# PNW has an average recommendation of:  2.70
# --------------------------------------------
# POOL has an average recommendation of:  2.30
# --------------------------------------------
# PPG has an average recommendation of:  2.20
# --------------------------------------------
# PPL has an average recommendation of:  2.50
# --------------------------------------------
# PRGO has an average recommendation of:  2.70
# --------------------------------------------
# PRU has an average recommendation of:  2.70
# --------------------------------------------
# PSA has an average recommendation of:  2.70
# --------------------------------------------
# PSX has an average recommendation of:  1.90
# --------------------------------------------
# PTC has an average recommendation of:  1.90
# --------------------------------------------
# PVH has an average recommendation of:  2.40
# --------------------------------------------
# PWR has an average recommendation of:  1.90
# --------------------------------------------
# PXD has an average recommendation of:  2.00
# --------------------------------------------
# PYPL has an average recommendation of:  1.80
# --------------------------------------------
# QCOM has an average recommendation of:  2.00
# --------------------------------------------
# QRVO has an average recommendation of:  2.20
# --------------------------------------------
# RCL has an average recommendation of:  2.60
# --------------------------------------------
# RE has an average recommendation of:  1.80
# --------------------------------------------
# REG has an average recommendation of:  2.40
# --------------------------------------------
# REGN has an average recommendation of:  2.00
# --------------------------------------------
# RF has an average recommendation of:  2.20
# --------------------------------------------
# RHI has an average recommendation of:  2.80
# --------------------------------------------
# RJF has an average recommendation of:  2.00
# --------------------------------------------
# RL has an average recommendation of:  2.40
# --------------------------------------------
# RMD has an average recommendation of:  2.60
# --------------------------------------------
# ROK has an average recommendation of:  2.60
# --------------------------------------------
# ROL has an average recommendation of:  2.30
# --------------------------------------------
# ROP has an average recommendation of:  2.50
# --------------------------------------------
# ROST has an average recommendation of:  1.90
# --------------------------------------------
# RSG has an average recommendation of:  2.20
# --------------------------------------------
# RTX has an average recommendation of:  2.00
# --------------------------------------------
# SBAC has an average recommendation of:  1.90
# --------------------------------------------
# SBUX has an average recommendation of:  2.20
# --------------------------------------------
# SCHW has an average recommendation of:  2.00
# --------------------------------------------
# SEE has an average recommendation of:  2.10
# --------------------------------------------
# SHW has an average recommendation of:  2.30
# --------------------------------------------
# SIVB has an average recommendation of:  2.30
# --------------------------------------------
# SJM has an average recommendation of:  3.20
# --------------------------------------------
# SLB has an average recommendation of:  2.10
# --------------------------------------------
# SNA has an average recommendation of:  2.70
# --------------------------------------------
# SNPS has an average recommendation of:  2.00
# --------------------------------------------
# SO has an average recommendation of:  2.60
# --------------------------------------------
# SPG has an average recommendation of:  2.40
# --------------------------------------------
# SPGI has an average recommendation of:  1.70
# --------------------------------------------
# SRE has an average recommendation of:  2.10
# --------------------------------------------
# STE has an average recommendation of:  2.00
# --------------------------------------------
# STT has an average recommendation of:  2.40
# --------------------------------------------
# STX has an average recommendation of:  2.50
# --------------------------------------------
# STZ has an average recommendation of:  2.10
# --------------------------------------------
# SWK has an average recommendation of:  2.20
# --------------------------------------------
# SWKS has an average recommendation of:  2.30
# --------------------------------------------
# SYF has an average recommendation of:  1.90
# --------------------------------------------
# SYK has an average recommendation of:  2.20
# --------------------------------------------
# SYY has an average recommendation of:  2.50
# --------------------------------------------
# T has an average recommendation of:  2.90
# --------------------------------------------
# TAP has an average recommendation of:  2.80
# --------------------------------------------
# TDG has an average recommendation of:  2.20
# --------------------------------------------
# TDY has an average recommendation of:  1.60
# --------------------------------------------
# TEL has an average recommendation of:  2.20
# --------------------------------------------
# TER has an average recommendation of:  2.20
# --------------------------------------------
# TFC has an average recommendation of:  2.30
# --------------------------------------------
# TFX has an average recommendation of:  1.60
# --------------------------------------------
# TGT has an average recommendation of:  1.90
# --------------------------------------------
# TJX has an average recommendation of:  1.80
# --------------------------------------------
# TMO has an average recommendation of:  1.70
# --------------------------------------------
# TMUS has an average recommendation of:  1.90
# --------------------------------------------
# TPR has an average recommendation of:  2.30
# --------------------------------------------
# TRMB has an average recommendation of:  1.90
# --------------------------------------------
# TROW has an average recommendation of:  3.00
# --------------------------------------------
# TRV has an average recommendation of:  2.70
# --------------------------------------------
# TSCO has an average recommendation of:  2.30
# --------------------------------------------
# TSLA has an average recommendation of:  2.80
# --------------------------------------------
# TSN has an average recommendation of:  2.20
# --------------------------------------------
# TT has an average recommendation of:  2.60
# --------------------------------------------
# TTWO has an average recommendation of:  2.20
# --------------------------------------------
# TWTR has an average recommendation of:  2.70
# --------------------------------------------
# TXN has an average recommendation of:  2.40
# --------------------------------------------
# TXT has an average recommendation of:  2.30
# --------------------------------------------
# TYL has an average recommendation of:  2.10
# --------------------------------------------
# UA has an average recommendation of:  3.50
# --------------------------------------------
# UAA has an average recommendation of:  2.70
# --------------------------------------------
# UAL has an average recommendation of:  2.60
# --------------------------------------------
# UDR has an average recommendation of:  2.40
# --------------------------------------------
# UHS has an average recommendation of:  2.40
# --------------------------------------------
# ULTA has an average recommendation of:  2.30
# --------------------------------------------
# UNH has an average recommendation of:  1.80
# --------------------------------------------
# UNM has an average recommendation of:  3.00
# --------------------------------------------
# UNP has an average recommendation of:  2.00
# --------------------------------------------
# UPS has an average recommendation of:  2.30
# --------------------------------------------
# URI has an average recommendation of:  2.40
# --------------------------------------------
# USB has an average recommendation of:  2.20
# --------------------------------------------
# V has an average recommendation of:  1.80
# --------------------------------------------
# VFC has an average recommendation of:  2.20
# --------------------------------------------
# VIAC has an average recommendation of:  2.90
# --------------------------------------------
# VLO has an average recommendation of:  1.80
# --------------------------------------------
# VMC has an average recommendation of:  2.30
# --------------------------------------------
# VNO has an average recommendation of:  3.00
# --------------------------------------------
# VRSK has an average recommendation of:  2.20
# --------------------------------------------
# VRSN has an average recommendation of:  2.00
# --------------------------------------------
# VRTX has an average recommendation of:  1.80
# --------------------------------------------
# VTR has an average recommendation of:  2.90
# --------------------------------------------
# VTRS has an average recommendation of:  2.40
# --------------------------------------------
# VZ has an average recommendation of:  2.70
# --------------------------------------------
# WAB has an average recommendation of:  2.30
# --------------------------------------------
# WAT has an average recommendation of:  3.20
# --------------------------------------------
# WBA has an average recommendation of:  3.00
# --------------------------------------------
# WDC has an average recommendation of:  2.20
# --------------------------------------------
# WEC has an average recommendation of:  3.10
# --------------------------------------------
# WELL has an average recommendation of:  2.60
# --------------------------------------------
# WFC has an average recommendation of:  2.20
# --------------------------------------------
# WHR has an average recommendation of:  2.70
# --------------------------------------------
# WLTW has an average recommendation of:  2.30
# --------------------------------------------
# WM has an average recommendation of:  2.40
# --------------------------------------------
# WMB has an average recommendation of:  2.00
# --------------------------------------------
# WMT has an average recommendation of:  1.90
# --------------------------------------------
# WRB has an average recommendation of:  2.80
# --------------------------------------------
# WRK has an average recommendation of:  2.10
# --------------------------------------------
# WST has an average recommendation of:  2.00
# --------------------------------------------
# WU has an average recommendation of:  2.90
# --------------------------------------------
# WY has an average recommendation of:  2.10
# --------------------------------------------
# WYNN has an average recommendation of:  2.30
# --------------------------------------------
# XEL has an average recommendation of:  2.90
# --------------------------------------------
# XLNX has an average recommendation of:  2.80
# --------------------------------------------
# XOM has an average recommendation of:  2.60
# --------------------------------------------
# XRAY has an average recommendation of:  1.90
# --------------------------------------------
# XYL has an average recommendation of:  2.90
# --------------------------------------------
# YUM has an average recommendation of:  2.50
# --------------------------------------------
# ZBH has an average recommendation of:  1.80
# --------------------------------------------
# ZBRA has an average recommendation of:  2.00
# --------------------------------------------
# ZION has an average recommendation of:  2.70
# --------------------------------------------
# ZTS has an average recommendation of:  1.90

# %%
dataframe
# Out:
#         Recommendations
# Company
# A                  1.90
# AAL                3.40
# AAP                2.20
# AAPL               2.00
# ABBV               2.00
# ...                 ...
# YUM                2.50
# ZBH                1.80
# ZBRA               2.00
# ZION               2.70
# ZTS                1.90
#
# [505 rows x 1 columns]
